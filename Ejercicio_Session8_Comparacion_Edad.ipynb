# %%
#1.-El doble de mi edad tiene 24 años, ¿cuántos años tengo?
edad1 = 24/2
print("Eu tenho ",int(edad1)," anos")
# Out:
# Eu tenho  12  anos

# %%
#2.- A un tercio de la edad de mi hermana la disminuyo en 15 años. Tengo 6 años. ¿Qué edad tiene?
edad2= (6+15)/(1/3)
print("Minha irmã tem ",int(edad2)," anos")
# Out:
# Minha irmã tem  63  anos

# %%
#3.-Determina quién es más grande
if edad1 > edad2:
	print("Eu sou mais velho que minha irmã")
elif edad1 < edad2:
	print("Minha irmã é mais velha que eu")
# Out:
# Minha irmã é mais velha que eu
